# %% [markdown]
# # Classification experiment of single (cutted) cells - MEL version

# %%
# %reload_ext autoreload
# %autoreload 2
from fastai import *
from fastai.vision import *
path = Path('./')

# %%
bs=16
data = ImageDataBunch.from_folder(Path('./DataMEL'),
        ds_tfms=get_transforms(), valid_pct=0.2, size=128, train='train', num_workers=4, bs=bs, test="test").normalize()

data.show_batch(rows=4)

# %%
data_test = (ImageList.from_folder(Path('./DataMEL/'))
        .split_by_folder(train='train', valid='test')
        .label_from_folder()).databunch().normalize()

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy, callback_fns=[ShowGraph])
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1,1e-2)
# Out:
# Total time: 06:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.308053</td>
#       <td>0.237315</td>
#       <td>0.911974</td>
#       <td>06:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unfreeze backbone of model, train for 10 epochs using cyclic learning rate scheme

# %%
learn.unfreeze()
learn.fit_one_cycle(10, slice(1e-3,1e-2), pct_start=0.05)
# Out:
# Total time: 1:14:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.370049</td>
#       <td>0.416299</td>
#       <td>0.872787</td>
#       <td>06:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.288310</td>
#       <td>0.258352</td>
#       <td>0.920848</td>
#       <td>06:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.335963</td>
#       <td>0.225840</td>
#       <td>0.917618</td>
#       <td>06:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.249807</td>
#       <td>0.175943</td>
#       <td>0.935365</td>
#       <td>07:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.210629</td>
#       <td>0.176752</td>
#       <td>0.932093</td>
#       <td>11:34</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.191316</td>
#       <td>0.162520</td>
#       <td>0.940316</td>
#       <td>08:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.185745</td>
#       <td>0.146053</td>
#       <td>0.944218</td>
#       <td>06:34</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.154680</td>
#       <td>0.140278</td>
#       <td>0.945981</td>
#       <td>06:34</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.138094</td>
#       <td>0.134404</td>
#       <td>0.948183</td>
#       <td>06:34</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.138246</td>
#       <td>0.133676</td>
#       <td>0.948855</td>
#       <td>06:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.data = data_test
#learn.validate(data.test_dl)
interp = ClassificationInterpretation.from_learner(learn, ds_type=DatasetType.Valid)
losses,idxs = interp.top_losses()

# %%
len(data.test_ds)==len(losses)==len(idxs)
interp.plot_top_losses(9, figsize=(15,11), heatmap=False)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Print confusion matrix, LaTeX style

# %%
print(" \\\\\n".join([" & ".join(map(str,line)) for line in interp.confusion_matrix()]))
# Out:
# 15693 & 10 & 386 & 18 \\
# 4 & 20986 & 555 & 6 \\
# 539 & 2594 & 24594 & 553 \\
# 21 & 8 & 398 & 25744

# %% [markdown]
# ## Find out test accuracy

# %%
c = interp.confusion_matrix()
accuracy = np.sum(c*np.eye(4))/np.sum(c)
print('Test accuracy: ',accuracy)
# Out:
# Test accuracy:  0.9447176714544724

# %%
learn.save('CellClassifier_128px_MEL.pth')
learn.export('CellClassifier_128px_MEL.pth')
