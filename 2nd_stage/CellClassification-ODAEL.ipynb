# %% [markdown]
# # Classification experiment of single (cutted) cells

# %%
# %reload_ext autoreload
# %autoreload 2
from fastai import *
from fastai.vision import *
path = Path('./')

# %%
bs=16
data = ImageDataBunch.from_folder(Path('./DataODAEL'),
        ds_tfms=get_transforms(), valid_pct=0.2, size=128, train='train', num_workers=4, bs=bs, test="test").normalize()

data.show_batch(rows=4)

# %%
data_test = (ImageList.from_folder(Path('./DataODAEL/'))
        .split_by_folder(train='train', valid='test')
        .label_from_folder()).databunch().normalize()

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy, callback_fns=[ShowGraph])
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1,1e-2)
# Out:
# Total time: 04:58 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.291344</td>
#       <td>0.297808</td>
#       <td>0.880006</td>
#       <td>04:57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unfreeze backbone of model, train for 3 cycles of 10 epochs each

# %%
learn.unfreeze()
learn.fit_one_cycle(10, slice(1e-3,1e-2), pct_start=0.05)
# Out:
# Total time: 1:05:26 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.325362</td>
#       <td>0.323285</td>
#       <td>0.859662</td>
#       <td>06:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.291308</td>
#       <td>0.222012</td>
#       <td>0.900734</td>
#       <td>06:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.242836</td>
#       <td>0.228957</td>
#       <td>0.900171</td>
#       <td>06:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.250415</td>
#       <td>0.192814</td>
#       <td>0.913155</td>
#       <td>06:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.225589</td>
#       <td>0.207856</td>
#       <td>0.911928</td>
#       <td>06:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.248964</td>
#       <td>0.211006</td>
#       <td>0.899302</td>
#       <td>06:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.225299</td>
#       <td>0.178550</td>
#       <td>0.918215</td>
#       <td>06:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.175258</td>
#       <td>0.165838</td>
#       <td>0.924502</td>
#       <td>06:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.163833</td>
#       <td>0.158351</td>
#       <td>0.927492</td>
#       <td>06:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.166581</td>
#       <td>0.156816</td>
#       <td>0.928004</td>
#       <td>08:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.data = data_test
#learn.validate(data.test_dl)
interp = ClassificationInterpretation.from_learner(learn, ds_type=DatasetType.Valid)
losses,idxs = interp.top_losses()

# %%
len(data.test_ds)==len(losses)==len(idxs)
interp.plot_top_losses(9, figsize=(15,11), heatmap=False)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Print confusion matrix, LaTeX style

# %%
print(" \\\\\n".join([" & ".join(map(str,line)) for line in interp.confusion_matrix()]))
# Out:
# 16051 & 0 & 35 & 22 \\
# 18 & 18761 & 3688 & 9 \\
# 101 & 2299 & 11114 & 111 \\
# 63 & 6 & 72 & 26031

# %% [markdown]
# ## Find out test accuracy

# %%
c = interp.confusion_matrix()
accuracy = np.sum(c*np.eye(4))/np.sum(c)
print('Test accuracy: ',accuracy)
# Out:
# Test accuracy:  0.9180413620647861

# %%
learn.save('CellClassifier_128px_ODAEL.pth')
learn.export('CellClassifier_128px_ODAEL.pth')
