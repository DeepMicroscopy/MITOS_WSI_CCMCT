# %% [markdown]
# # Classification experiment of single (cutted) cells - 3WSI dataset version

# %%
# %reload_ext autoreload
# %autoreload 2
from fastai import *
from fastai.vision import *
path = Path('./')

# %%
bs=16
data = ImageDataBunch.from_folder(Path('./DataODAEL_3WSI'),
        ds_tfms=get_transforms(), valid_pct=0.2, size=128, train='train', num_workers=4, bs=bs, test="test").normalize()

data.show_batch(rows=4)

# %%
data_test = (ImageList.from_folder(Path('./DataODAEL_3WSI/'))
        .split_by_folder(train='train', valid='test')
        .label_from_folder()).databunch().normalize()

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy, callback_fns=[ShowGraph])
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1,1e-2)
# Out:
# Total time: 04:53 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.338459</td>
#       <td>0.273893</td>
#       <td>0.876052</td>
#       <td>04:53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unfreeze backbone of model, train for 10 epochs using cyclic learning rate scheme

# %%
learn.unfreeze()
learn.fit_one_cycle(10, slice(1e-3,1e-2), pct_start=0.05)
# Out:
# Total time: 54:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.448889</td>
#       <td>0.298258</td>
#       <td>0.868111</td>
#       <td>04:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.345931</td>
#       <td>0.292671</td>
#       <td>0.882415</td>
#       <td>04:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.340996</td>
#       <td>0.244091</td>
#       <td>0.893143</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.268033</td>
#       <td>0.230597</td>
#       <td>0.900032</td>
#       <td>05:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.282455</td>
#       <td>0.209859</td>
#       <td>0.909024</td>
#       <td>05:49</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.237820</td>
#       <td>0.208794</td>
#       <td>0.910654</td>
#       <td>05:51</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.224170</td>
#       <td>0.198282</td>
#       <td>0.914914</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.195882</td>
#       <td>0.189532</td>
#       <td>0.915545</td>
#       <td>05:40</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.206676</td>
#       <td>0.183069</td>
#       <td>0.919068</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.208431</td>
#       <td>0.181832</td>
#       <td>0.919173</td>
#       <td>05:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.data = data_test
#learn.validate(data.test_dl)
interp = ClassificationInterpretation.from_learner(learn, ds_type=DatasetType.Valid)
losses,idxs = interp.top_losses()

# %%
len(data.test_ds)==len(losses)==len(idxs)
interp.plot_top_losses(9, figsize=(15,11), heatmap=False)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Print confusion matrix, LaTeX style

# %%
print(" \\\\\n".join([" & ".join(map(str,line)) for line in interp.confusion_matrix()]))
# Out:
# 16012 & 0 & 10 & 86 \\
# 90 & 11949 & 10296 & 141 \\
# 521 & 296 & 12028 & 780 \\
# 24 & 2 & 19 & 26127

# %% [markdown]
# ## Find out test accuracy

# %%
c = interp.confusion_matrix()
accuracy = np.sum(c*np.eye(4))/np.sum(c)
print('Test accuracy: ',accuracy)
# Out:
# Test accuracy:  0.8435207512024597

# %%
learn.save('CellClassifier_128px_3WSI.pth')
learn.export('CellClassifier_128px_3WSI.pth')
