# %% [markdown]
# # Classification experiment of single (cutted) cells - 50 HPF dataset version

# %%
# %reload_ext autoreload
# %autoreload 2
from fastai import *
from fastai.vision import *
path = Path('./')

# %%
bs=16
data = ImageDataBunch.from_folder(Path('./Data50HPF'),
        ds_tfms=get_transforms(), valid_pct=0.2, size=128, train='train', num_workers=4, bs=bs, test="test").normalize()

data.show_batch(rows=4)

# %%
data_test = (ImageList.from_folder(Path('./Data50HPF/'))
        .split_by_folder(train='train', valid='test')
        .label_from_folder()).databunch().normalize()

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy, callback_fns=[ShowGraph])
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(1,1e-2)
# Out:
# Total time: 00:42 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.317411</td>
#       <td>0.248507</td>
#       <td>0.903785</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unfreeze backbone of model, train for 10 epochs using cyclic learning rate scheme

# %%
learn.unfreeze()
learn.fit_one_cycle(10, slice(1e-3,1e-2), pct_start=0.05)
# Out:
# Total time: 08:08 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.395034</td>
#       <td>1.960994</td>
#       <td>0.618167</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.326534</td>
#       <td>0.777506</td>
#       <td>0.744491</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.265807</td>
#       <td>0.200616</td>
#       <td>0.910681</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.283659</td>
#       <td>0.168955</td>
#       <td>0.918755</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.236203</td>
#       <td>0.157598</td>
#       <td>0.930698</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.189494</td>
#       <td>0.167868</td>
#       <td>0.921783</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.172491</td>
#       <td>0.163635</td>
#       <td>0.918923</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.155355</td>
#       <td>0.130108</td>
#       <td>0.940118</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.149920</td>
#       <td>0.125539</td>
#       <td>0.941800</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.147004</td>
#       <td>0.125408</td>
#       <td>0.941800</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.data = data_test
#learn.validate(data.test_dl)
interp = ClassificationInterpretation.from_learner(learn, ds_type=DatasetType.Valid)
losses,idxs = interp.top_losses()

# %%
len(data.test_ds)==len(losses)==len(idxs)
interp.plot_top_losses(9, figsize=(15,11), heatmap=False)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %% [markdown]
# ## Print confusion matrix, LaTeX style

# %%
print(" \\\\\n".join([" & ".join(map(str,line)) for line in interp.confusion_matrix()]))
# Out:
# 2147 & 0 & 6 & 2 \\
# 0 & 1260 & 189 & 0 \\
# 8 & 194 & 529 & 2 \\
# 4 & 0 & 7 & 3569

# %% [markdown]
# ## Find out test accuracy

# %%
c = interp.confusion_matrix()
accuracy = np.sum(c*np.eye(4))/np.sum(c)
print('Test accuracy: ',accuracy)
# Out:
# Test accuracy:  0.9479600858911204

# %%
learn.save('CellClassifier_128px_50HPF.pth')
learn.export('CellClassifier_128px_50HPF.pth')
